# %% [markdown]
# # 9. Obtendo Dados
#
# ### stdin e stdout
#
# * Se os scripts de Python são executados via linha de comando, é possível canalizar (pipe) os dados usando sys.stdin e sys.stdout.
#
# * Abaixo um script que lê linhas de um texto e devolve as que combinarem como uma expressão regular:

# %% [markdown]
# ~~~ Python
# # Salvo como egrep.py
# import sys, re
#
# # sys.argv é a lista dos argumentos da linha de comandos
# # sys.argv [0] é o nome do programa em si
# # sys.argv [1] será o regex especificado na linha de comandos
# regex = sys.argv[1]
#
# # para cada linha passada pelo script
# for line in sys.stdin:
#     # se combinar com o regex, escreva-o para o stdout
#     if re.search(regex, line):
#         sys.stdout.write(line)
# ~~~

# %% [markdown]
# * O próximo conta as linhas recebidas e exibe a contagem:

# %% [markdown]
# ~~~ Python
# # Salvo como line_count.py
# import sys
#
# count = 0
# for line in sys.stdin:
#     count += 1
#
# # print vai para sys.stdout
# print(count)
# ~~~

# %% [markdown]
# * E poderia usá-los utilizando o seguinte comando:

# %%
cat Dados/File.txt | python Codigos/egrep.py "[0-9]" | python Codigos/line_count.py
# Out:
# 3

# %% [markdown]
# * O caractere | (pipe) significa "use a saída do comando da esquerda como entrada do comando da direita"
# * Permite a construção de pipelines elaborados de processamento de dados.
#
# * O script abaixo conta as palavras e exibe as mais comuns:

# %% [markdown]
# ~~~ Python
# # Salvo como most_commom_words.py
# import sys
# from collections import Counter
#
# # passa o número de palavras como primeiro argumento
# try:
#     num_words = int(sys.argv[1])
# except:
#     print ()
#     sys.exit(1) # código de saída não-zero indica erro
#
# counter = Counter(word.lower() # palavras em minúsculas
#                   for line in sys.stdin #
#                   for word in line.strip().split() # se separam por espaços
#                   if word)
#
# # pula as 'palavras' vazias
# for word, count in counter.most_common(num_words):
#     sys.stdout.write(str(count))"usage: most_common_words.py num_words"
#     sys.stdout.write("\t")
#     sys.stdout.write(word)
#     sys.stdout.write("\n")
#
# ~~~
#
# * E finalmente pode ser chamado assim:

# %%
cat Dados/some_text.txt | python Codigos/most_common_words.py 5
# Out:
# 10	and
# 10	to
# 8	the
# 7	of
# 4	in

# %% [markdown]
# ### Lendo Arquivos
#
# * É possível ler a partir de e escrever nos arquivos através do código python.
#
# #### O básico de arquivos texto
#
# * O primeiro passo é obter um objeto de arquivo usando *open*:
#
# ~~~ Python
# # 'r' significa somente leitura
# file_for_reading = open('reading_file.txt', 'r')
#
# # 'w' é escrever - - destruirá o arquivo se ele já existir!
# file_for_writing = open('writing_file.txt', 'w')
#
# # 'a' é anexar - - para adicionar ao final do arquivo
# file_for_appending = open('appending_file.txt', 'a')
#
# # não se esqueça de fechar os arquivos ao terminar
# file_for_writing.close()
# ~~~
#
# * O *open* deve ser usado em um bloco *with*, pois fecha automaticamente os arquivos:
#
# ~~~ Python
# with open(filename,'r') as f:
#     data = function_that_gets_data_from(f)
#
# # neste ponto f já foi fechado, não tente usá-lo
# process(data)
# ~~~
#
# * Se você precisar ler o arquivo inteiro, pode-se iterar sobre as linhas do arquivo usando for:
#
# ~~~ Python
# starts_with_hash = 0
#
# with open('input.txt','r') as f:
#     for line in file: # observe cada linha do arquivo
#         if re.match("^#",line): # use um regex para ver se começa com '#'
#             starts_with_hash += 1 # se começar, adicione 1 à contagem
# ~~~
#
# * Toda linha obtida dessa forma termina com um caractere '\n' (new line), frequentemente iremos removê-lo.
#
# #### Arquivos delimitados
#
# * Com frequência você trabalhará com arquivos com muitos dados separados por vírgula (comma-separated) ou por tabulação (tab-separated).
#    * Cada linha possui diversos campos com virgula ou tabulação inidicando o fim de um campo.
#
#
# * Se tivéssemos um arquivo de preçoes de ações delimitado por tabulações:

# %%
cat Dados/tab_delimited_stock_prices.txt
# Out:
# 6/20/2014	AAPL	90.91
# 6/20/2014	MSFT	41.68
# 6/20/2014	FB	64.5
# 6/19/2014	AAPL	91.86
# 6/19/2014	MSFT	41.51
# 6/19/2014	FB	64.34

# %% [markdown]
# * Podemos processá-los com:

# %%
import csv

with open('Dados/tab_delimited_stock_prices.txt','r') as f:
    reader = csv.reader(f, delimiter='\t')
    for row in reader:
        date = row[0]
        symbol = row[1]
        closing_price = float(row[2])
        print(date, symbol, closing_price)
# Out:
# 6/20/2014 AAPL 90.91
# 6/20/2014 MSFT 41.68
# 6/20/2014 FB 64.5
# 6/19/2014 AAPL 91.86
# 6/19/2014 MSFT 41.51
# 6/19/2014 FB 64.34

# %% [markdown]
# * Se o arquivo possui cabeçalho você pode pular a linha com reader.next() ou obter cada linha como um dicionário com csv.DictReader().

# %%
cat Dados/colon_delimited_stock_prices.txt
# Out:
# date:symbol:closing_price
# 6/20/2014:AAPL:90.91
# 6/20/2014:MSFT:41.68
# 6/20/2014:FB:64.5

# %%
with open('Dados/colon_delimited_stock_prices.txt', 'r') as f:
    reader = csv.DictReader(f, delimiter=':')
    for row in reader:
        date = row["date"]
        symbol = row["symbol"]
        closing_price = float(row["closing_price"])
        print(date, symbol, closing_price)
# Out:
# 6/20/2014 AAPL 90.91
# 6/20/2014 MSFT 41.68
# 6/20/2014 FB 64.5

# %% [markdown]
# * Se o arquivo não tiver cabeçalhos você ainda pode usar passar a chave a eles como o parâmetro fieldnames.
# * Você pode escrever os dados delimitados usando csv.writer()

# %%
today_prices = { 'AAPL' : 90.91, 'MSFT' : 41.68, 'FB' : 64.5 }

with open('Dados/comma_delimited_stock_prices.txt','w') as f:
    writer = csv.writer(f, delimiter=',')
    for stock, price in today_prices.items():
        writer.writerow([stock, price])

# %%
cat Dados/comma_delimited_stock_prices.txt
# Out:
# AAPL,90.91
# MSFT,41.68
# FB,64.5

# %% [markdown]
# * Uma forma errada de fazer isso seria:

# %%
results = [["test1", "success", "Monday"],
           ["test2", "success, kind of", "Tuesday"],
           ["test3", "failure, kind of", "Wednesday"],
           ["test4", "failure, utter", "Thursday"]]

# não faça isso!
with open('Dados/bad_csv.txt', 'w') as f:
    for row in results:
        f.write(",".join(map(str, row))) # talvez tenha muitas vírgulas nele!
        f.write("\n") # a linha pode ter newlines também!

# %%
cat Dados/bad_csv.txt
# Out:
# test1,success,Monday
# test2,success, kind of,Tuesday
# test3,failure, kind of,Wednesday
# test4,failure, utter,Thursday

# %% [markdown]
# ### Extraindo Dados da Internet
#
# * Outra maneira de obter dados é extraindo de páginas web.
# * Não é uma tarefa tão simples.
#
# #### HTML e sua subsequente pesquisa
#
# * HTML não é bem formulado, muito menos comentado. Necessitamos de ajuda para entender tudo isso.
# * Para extrair esses dados utilizamos a biblioteca BeautifulSoup.
#   * Constrói uma ávore a partir de elementos da página.
#   * Fornece interface simples para acessá-los.
#
#
# * Usaremos a biblioteca requests para a comunicação com o HTTP.
# * E utilizaremos a biblioteca html5lib como interpretador HTML.
# * Abaixo, um exemplo de uso das bibliotecas citadas, após isso, serão usados alguns métodos simples.

# %%
from bs4 import BeautifulSoup
import requests

html = requests.get("http://www.example.com").text
soup = BeautifulSoup(html, 'html5lib')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8"/>
#     <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#     <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
#
#
# </body></html>

# %% [markdown]
# * Depois, serão trabalhados utilizando as tags de marcações do HTML.
# * Veja o exemplo abaixo que pega elementos da tag p:

# %%
first_paragraph = soup.find('p')
# ou
first_paragraph_alt = soup.p

# %%
print(first_paragraph)
print()
print(first_paragraph_alt)
# Out:
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>

# %% [markdown]
# * É possível obter o conteúdo da tag usando a propriedade text:

# %%
first_paragraph_text = soup.p.text
first_paragraph_words = soup.p.text.split()

# %%
print(first_paragraph_text)
print()
print(first_paragraph_words)
# Out:
# This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.
#
# ['This', 'domain', 'is', 'for', 'use', 'in', 'illustrative', 'examples', 'in', 'documents.', 'You', 'may', 'use', 'this', 'domain', 'in', 'literature', 'without', 'prior', 'coordination', 'or', 'asking', 'for', 'permission.']

# %% [markdown]
# * Podemos extrair os atributos de uma marcação tratando como um dict:

# %%
first_paragraph_id = soup.p['id'] # retorna um KeyError se não tiver 'id'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-36beb3d2d001> in <module>
# ----> 1 first_paragraph_id = soup.p['id'] # retorna um KeyError se não tiver 'id'
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#    1069         """tag[key] returns the value of the 'key' attribute for the tag,
#    1070         and throws an exception if it's not there."""
# -> 1071         return self.attrs[key]
#    1072
#    1073     def __iter__(self):
#
# KeyError: 'id'

# %%
first_paragraph_id2 = soup.p.get('id') # retorna None se não tiver 'id'
print(first_paragraph_id2)
# Out:
# None

# %% [markdown]
# * Pode-se obter múltiplas marcações ao mesmo tempo:

# %%
all_paragraphs = soup.find_all('p') # ou apenas soup('p')
paragraphs_with_ids = [p for p in soup('p') if p.get('id')]

# %% [markdown]
# * Também podemos encontrar marcações com uma *class* específica:

# %%
important_paragraphs = soup('p', {'class' : 'important'})
important_paragraphs2 = soup('p', 'important')
important_paragraphs3 = [p for p in soup('p')
                         if 'important' in p.get('class', [])]

# %% [markdown]
# * Essas funcionalidades nos possibilitarão fazer algumas coisas.
# * Para aplicações mais complicadas, consulte a documentação.
#
# ### Usando APIs
#
# * Muitos websites e serviços web fornecem APIs que permitem a solicitação de dados estruturados.
#
# #### JSON (e XML)
#
# * O HTTP é um protocolo que permite a transferência de texto.
# * Os dados que você solicita por uma API devem ser serializados por meio de strings.
# * Geralmente essa serialização é feita através de JSON.
# * Pela sua estrutura parecer muito com dicts python, facilita a interpretação das strings:

# %%
{"title" : "Data Science Book",
 "author" : "Joel Grus",
 "publicationYear" : 2014,
 "topics" : [ "data", "science", "data science"]}
# Out:
# {'title': 'Data Science Book',
#  'author': 'Joel Grus',
#  'publicationYear': 2014,
#  'topics': ['data', 'science', 'data science']}

# %% [markdown]
# * Podemos analisar JSON utilizando o módulo json do Python.
# * Usaremos a função loads para desserializar um objeto JSON:

# %%
import json
serialized = """{ "title" : "Data Science Book", "author" : "Joel Grus", "publicationYear" : 2014,
"topics" : [ "data", "science", "data science"] }"""

# analisa o json para criar um dict do Python
deserialized = json.loads(serialized)
if "data science" in deserialized["topics"]:
    print (deserialized)
# Out:
# {'title': 'Data Science Book', 'author': 'Joel Grus', 'publicationYear': 2014, 'topics': ['data', 'science', 'data science']}

# %% [markdown]
# * As vezes a API fornece apenas respostas em XML.
# * Para tal pode-se usar o módulo BeautifulSoup para obter os dados.
#
# #### Usando uma API não autenticada
#
# * A maioria das APIs requerem uma autenticação de quem deseja usar.
# * Daremos uma olhada na API do github para praticar acessos não autenticados:

# %%
import requests, json
endpoint = "https://api.github.com/users/acucenarodrigues1998/repos"
repos = json.loads(requests.get(endpoint).text)

# %% [markdown]
# * repos é uma list de dicts do Python, cada uma representando um repositorio público no meu github.
# * Com esses dados, é possível descobrir em quais meses e dias eu possuo mais tendência a criar repositórios.
# * As datas na resposta são strings.
# * Usaremos o módulo dateutil para analisar as datas.
# * Usaremos a função dateutil.parser.parse.

# %%
from dateutil.parser import parse
from collections import Counter

dates = [parse(repo["created_at"]) for repo in repos]
month_counts = Counter(date.month for date in dates)
weekday_counts = Counter(date.weekday() for date in dates)

print("Meses com mais repositórios criados:")
print(list(month_counts.keys()))
print("Dias com mais repositórios criados:")
print(list(weekday_counts.keys()))
# Out:
# Meses com mais repositórios criados:
# [12, 2, 10, 8, 9, 11]
# Dias com mais repositórios criados:
# [0, 2, 1, 3, 4]

# %% [markdown]
# * Podemos pegar as linguagens dos 5 últimos repos criados:

# %%
last_5_repositories = sorted(repos, key=lambda r: r["created_at"], reverse=True)[:5]
last_5_languages = [repo["language"] for repo in last_5_repositories]
print(last_5_languages)
# Out:
# ['Jupyter Notebook', 'Jupyter Notebook', 'Python', 'Java', 'Jupyter Notebook']

# %% [markdown]
# * Existem bibliotecas que omitem o baixo nível do acesso a APIs, como feito acima. Elas podem poupar muito trabalho.
#
# ### Exemplo: Usando as APIs do Twitter
#
# * O Twitter é uma grande fonte de dados para trabalhar.
# * Você pode usá-la para praticamente tudo que imaginar, desde que possua o acesso aos dados.
# * Esse acesso pode ser obtido através de uma API.
# * Para interagir com a API, usaremos a biblioteca Twython.
#
# #### Obtendo Credenciais
#
# * Para usar a API do Twitter são necessárias algumas credenciais.
# * Para obtê-las, é necessário acessar o site https://apps.twitter.com, criar uma conta de desenvolvedor e em seguida criar um app.
#   * Não colocarei o passo-a-passo, pois, são frequentes as mudanças nesse processo.
#
#
# * Após a criação do APP, são geradas a chave e o segredo do consumidor que servem para identificar qual APP está acessando os dados
#
# #### Usando Twython
#
# * Utilizaremos o Search API que necessita apenas da chave e do segredo do consumidor.

# %%
from twython import Twython

CONSUMER_KEY = 
CONSUMER_SECRET = 
ACCESS_TOKEN = 
ACCESS_TOKEN_SECRET = 

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

# Busca por tweets contendo a frase "data science"
for status in twitter.search(q='"data science"')["statuses"]:
    user = status["user"]["screen_name"].encode('utf-8')
    text = status["text"].encode('utf-8')
    print("{}: {}".format(user, text))
    print()
# Out:
# b'_SelloM': b'No ways. Code is profound. Maybe data science or computational thinking but / data / digital literacy but coding at\xe2\x80\xa6 https://t.co/nDxKWEtWxr'
#
# b'elfprince13': b'RT @genevievemp: So many statistical methods were invented by farmers for farming. It\xe2\x80\x99s the first application area for \xe2\x80\x98data science\xe2\x80\x99.\n1/2'
#
# b'Anna_LisaRob': b'RT @NickBiniker: Higher education is not at its best when it is facing inward, but outward - @mikekrauseTN Congratulations @capigian and te\xe2\x80\xa6'
#
# b'grjenkin': b'The top 3 mistakes companies make when adopting AI: Amazon head of data science at AWS machine learning solutions l\xe2\x80\xa6 https://t.co/QIx2xutHFm'
#
# b'capgemini_ch': b"RT @Capgemini: We're pleased to announce today the acquisition of Advectas, a leading business intelligence and data science company in Sca\xe2\x80\xa6"
#
# b'Adam_IT_': b'RT @PythonDevelop: Python For Data Science - How to use Data Science with Python\n\n\xe2\x98\x9e https://t.co/VXKMxqBAeA\n\n#python #programming https://t\xe2\x80\xa6'
#
# b'FranceDevOps': b'RT @JLB_orcl: Oracle #cloud helps #datascience teams improve #ML model productivity &amp; collaboration to deliver data-driven business growth\xe2\x80\xa6'
#
# b'ECON_Automation': b'Identificar tendencias por medio del reconocimiento de patrones que pueden implementarse en estrategias o en modelo\xe2\x80\xa6 https://t.co/aP93tuoE5O'
#
# b'Adam_IT_': b'RT @python_devv: Python For Data Science - How to use Data Science with Python\n\n\xe2\x98\x9e https://t.co/VdbINe6vjN\n\n#python #programming https://t.c\xe2\x80\xa6'
#
# b'mikekrauseTN': b'RT @NickBiniker: Higher education is not at its best when it is facing inward, but outward - @mikekrauseTN Congratulations @capigian and te\xe2\x80\xa6'
#
# b'harveymudd': b'RT @MathFeed: Researcher finds a mathematical pattern in human conflict using data science https://t.co/KJ0pLVp3zq'
#
# b'lauriehines': b'RT @OracleResearch: #Oracle is helping researchers achieve results even more quickly now with the new VM for #DataScience and #AI on #Oracl\xe2\x80\xa6'
#
# b'p_nombula': b'What an adventure, I overcame so many obstacles in my personal and professional life - from completing my degrees t\xe2\x80\xa6 https://t.co/SdJXYdzlC9'
#
# b'ResearchRocks': b'Are you a college student or career switcher interested in learning about market research, data science and/or cons\xe2\x80\xa6 https://t.co/SQF2MFF3mA'
#
# b'JustBeMentalist': b'RT @webAnalyste: Gartner\xe2\x80\x99s 2020 Magic Quadrant for Data Science and Machine Learning Tools \xe2\x80\x93 check out the new Leaders! https://t.co/n7OaTZ\xe2\x80\xa6'

# %% [markdown]
# * Isso não é muito interessante. O Search API mostra apenas a parte dos resultados que ele quer.
# * Para mais dados, é necessário utilizar o Streaming API.

# %%
from twython import TwythonStreamer

# Anexando dados a variável global para simplificar o exemplo.
tweets = []

class MyStreamer(TwythonStreamer):
    
    def on_success(self, data):
        # O que fazer quando o twitter manda dados.
        # Os dados serão dicts de python representando um twitter.
        
        # Coletar dados apenas em inglês
        if data['lang'] == 'en':
            tweets.append(data)
            print("Received tweet #{}".format(len(tweets)))
            
        if len(tweets) >= 1000:
            self.disconnect()
            
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

# %% [markdown]
# * MyStreamer vai se connectar com o stream do Twitter e esperar que o twitter o abasteça de dados.
# * Ao receber dados, ele passa para on_success() que anexa a lista de tweets se a lingua for inglesa e desconecta após obter 1000 tweets.
# * Agora vamos testá-lo:

# %%
stream = MyStreamer(CONSUMER_KEY, CONSUMER_SECRET,
                   ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# Começa a consumir status públicos que contenham a palavra chave "data"
stream.statuses.filter(track='data')

# Se quisessemos começar a consumir uma amostra dos dados coletados
stream.statuses.sample()
# Out:
# Received tweet #1
# Received tweet #2
# Received tweet #3
# Received tweet #4
# Received tweet #5
# Received tweet #6
# Received tweet #7
# Received tweet #8
# Received tweet #9
# Received tweet #10
# Received tweet #11
# Received tweet #12
# Received tweet #13
# Received tweet #14
# Received tweet #15
# Received tweet #16
# Received tweet #17
# Received tweet #18
# Received tweet #19
# Received tweet #20
# Received tweet #21
# Received tweet #22
# Received tweet #23
# Received tweet #24
# Received tweet #25
# Received tweet #26
# Received tweet #27
# Received tweet #28
# Received tweet #29
# Received tweet #30
# Received tweet #31
# Received tweet #32
# Received tweet #33
# Received tweet #34
# Received tweet #35
# Received tweet #36
# Received tweet #37
# Received tweet #38
# Received tweet #39
# Received tweet #40
# Received tweet #41
# Received tweet #42
# Received tweet #43
# Received tweet #44
# Received tweet #45
# Received tweet #46
# Received tweet #47
# Received tweet #48
# Received tweet #49
# Received tweet #50
# Received tweet #51
# Received tweet #52
# Received tweet #53
# Received tweet #54
# Received tweet #55
# Received tweet #56
# Received tweet #57
# Received tweet #58
# Received tweet #59
# Received tweet #60
# Received tweet #61
# Received tweet #62
# Received tweet #63
# Received tweet #64
# Received tweet #65
# Received tweet #66
# Received tweet #67
# Received tweet #68
# Received tweet #69
# Received tweet #70
# Received tweet #71
# Received tweet #72
# Received tweet #73
# Received tweet #74
# Received tweet #75
# Received tweet #76
# Received tweet #77
# Received tweet #78
# Received tweet #79
# Received tweet #80
# Received tweet #81
# Received tweet #82
# Received tweet #83
# Received tweet #84
# Received tweet #85
# Received tweet #86
# Received tweet #87
# Received tweet #88
# Received tweet #89
# Received tweet #90
# Received tweet #91
# Received tweet #92
# Received tweet #93
# Received tweet #94
# Received tweet #95
# Received tweet #96
# Received tweet #97
# Received tweet #98
# Received tweet #99
# Received tweet #100
# Received tweet #101
# Received tweet #102
# Received tweet #103
# Received tweet #104
# Received tweet #105
# Received tweet #106
# Received tweet #107
# Received tweet #108
# Received tweet #109
# Received tweet #110
# Received tweet #111
# Received tweet #112
# Received tweet #113
# Received tweet #114
# Received tweet #115
# Received tweet #116
# Received tweet #117
# Received tweet #118
# Received tweet #119
# Received tweet #120
# Received tweet #121
# Received tweet #122
# Received tweet #123
# Received tweet #124
# Received tweet #125
# Received tweet #126
# Received tweet #127
# Received tweet #128
# Received tweet #129
# Received tweet #130
# Received tweet #131
# Received tweet #132
# Received tweet #133
# Received tweet #134
# Received tweet #135
# Received tweet #136
# Received tweet #137
# Received tweet #138
# Received tweet #139
# Received tweet #140
# Received tweet #141
# Received tweet #142
# Received tweet #143
# Received tweet #144
# Received tweet #145
# Received tweet #146
# Received tweet #147
# Received tweet #148
# Received tweet #149
# Received tweet #150
# Received tweet #151
# Received tweet #152
# Received tweet #153
# Received tweet #154
# Received tweet #155
# Received tweet #156
# Received tweet #157
# Received tweet #158
# Received tweet #159
# Received tweet #160
# Received tweet #161
# Received tweet #162
# Received tweet #163
# Received tweet #164
# Received tweet #165
# Received tweet #166
# Received tweet #167
# Received tweet #168
# Received tweet #169
# Received tweet #170
# Received tweet #171
# Received tweet #172
# Received tweet #173
# Received tweet #174
# Received tweet #175
# Received tweet #176
# Received tweet #177
# Received tweet #178
# Received tweet #179
# Received tweet #180
# Received tweet #181
# Received tweet #182
# Received tweet #183
# Received tweet #184
# Received tweet #185
# Received tweet #186
# Received tweet #187
# Received tweet #188
# Received tweet #189
# Received tweet #190
# Received tweet #191
# Received tweet #192
# Received tweet #193
# Received tweet #194
# Received tweet #195
# Received tweet #196
# Received tweet #197
# Received tweet #198
# Received tweet #199
# Received tweet #200
# Received tweet #201
# Received tweet #202
# Received tweet #203
# Received tweet #204
# Received tweet #205
# Received tweet #206
# Received tweet #207
# Received tweet #208
# Received tweet #209
# Received tweet #210
# Received tweet #211
# Received tweet #212
# Received tweet #213
# Received tweet #214
# Received tweet #215
# Received tweet #216
# Received tweet #217
# Received tweet #218
# Received tweet #219
# Received tweet #220
# Received tweet #221
# Received tweet #222
# Received tweet #223
# Received tweet #224
# Received tweet #225
# Received tweet #226
# Received tweet #227
# Received tweet #228
# Received tweet #229
# Received tweet #230
# Received tweet #231
# Received tweet #232
# Received tweet #233
# Received tweet #234
# Received tweet #235
# Received tweet #236
# Received tweet #237
# Received tweet #238
# Received tweet #239
# Received tweet #240
# Received tweet #241
# Received tweet #242
# Received tweet #243
# Received tweet #244
# Received tweet #245
# Received tweet #246
# Received tweet #247
# Received tweet #248
# Received tweet #249
# Received tweet #250
# Received tweet #251
# Received tweet #252
# Received tweet #253
# Received tweet #254
# Received tweet #255
# Received tweet #256
# Received tweet #257
# Received tweet #258
# Received tweet #259
# Received tweet #260
# Received tweet #261
# Received tweet #262
# Received tweet #263
# Received tweet #264
# Received tweet #265
# Received tweet #266
# Received tweet #267
# Received tweet #268
# Received tweet #269
# Received tweet #270
# Received tweet #271
# Received tweet #272
# Received tweet #273
# Received tweet #274
# Received tweet #275
# Received tweet #276
# Received tweet #277
# Received tweet #278
# Received tweet #279
# Received tweet #280
# Received tweet #281
# Received tweet #282
# Received tweet #283
# Received tweet #284
# Received tweet #285
# Received tweet #286
# Received tweet #287
# Received tweet #288
# Received tweet #289
# Received tweet #290
# Received tweet #291
# Received tweet #292
# Received tweet #293
# Received tweet #294
# Received tweet #295
# Received tweet #296
# Received tweet #297
# Received tweet #298
# Received tweet #299
# Received tweet #300
# Received tweet #301
# Received tweet #302
# Received tweet #303
# Received tweet #304
# Received tweet #305
# Received tweet #306
# Received tweet #307
# Received tweet #308
# Received tweet #309
# Received tweet #310
# Received tweet #311
# Received tweet #312
# Received tweet #313
# Received tweet #314
# Received tweet #315
# Received tweet #316
# Received tweet #317
# Received tweet #318
# Received tweet #319
# Received tweet #320
# Received tweet #321
# Received tweet #322
# Received tweet #323
# Received tweet #324
# Received tweet #325
# Received tweet #326
# Received tweet #327
# Received tweet #328
# Received tweet #329
# Received tweet #330
# Received tweet #331
# Received tweet #332
# Received tweet #333
# Received tweet #334
# Received tweet #335
# Received tweet #336
# Received tweet #337
# Received tweet #338
# Received tweet #339
# Received tweet #340
# Received tweet #341
# Received tweet #342
# Received tweet #343
# Received tweet #344
# Received tweet #345
# Received tweet #346
# Received tweet #347
# Received tweet #348
# Received tweet #349
# Received tweet #350
# Received tweet #351
# Received tweet #352
# Received tweet #353
# Received tweet #354
# Received tweet #355
# Received tweet #356
# Received tweet #357
# Received tweet #358
# Received tweet #359
# Received tweet #360
# Received tweet #361
# Received tweet #362
# Received tweet #363
# Received tweet #364
# Received tweet #365
# Received tweet #366
# Received tweet #367
# Received tweet #368
# Received tweet #369
# Received tweet #370
# Received tweet #371
# Received tweet #372
# Received tweet #373
# Received tweet #374
# Received tweet #375
# Received tweet #376
# Received tweet #377
# Received tweet #378
# Received tweet #379
# Received tweet #380
# Received tweet #381
# Received tweet #382
# Received tweet #383
# Received tweet #384
# Received tweet #385
# Received tweet #386
# Received tweet #387
# Received tweet #388
# Received tweet #389
# Received tweet #390
# Received tweet #391
# Received tweet #392
# Received tweet #393
# Received tweet #394
# Received tweet #395
# Received tweet #396
# Received tweet #397
# Received tweet #398
# Received tweet #399
# Received tweet #400
# Received tweet #401
# Received tweet #402
# Received tweet #403
# Received tweet #404
# Received tweet #405
# Received tweet #406
# Received tweet #407
# Received tweet #408
# Received tweet #409
# Received tweet #410
# Received tweet #411
# Received tweet #412
# Received tweet #413
# Received tweet #414
# Received tweet #415
# Received tweet #416
# Received tweet #417
# Received tweet #418
# Received tweet #419
# Received tweet #420
# Received tweet #421
# Received tweet #422
# Received tweet #423
# Received tweet #424
# Received tweet #425
# Received tweet #426
# Received tweet #427
# Received tweet #428
# Received tweet #429
# Received tweet #430
# Received tweet #431
# Received tweet #432
# Received tweet #433
# Received tweet #434
# Received tweet #435
# Received tweet #436
# Received tweet #437
# Received tweet #438
# Received tweet #439
# Received tweet #440
# Received tweet #441
# Received tweet #442
# Received tweet #443
# Received tweet #444
# Received tweet #445
# Received tweet #446
# Received tweet #447
# Received tweet #448
# Received tweet #449
# Received tweet #450
# Received tweet #451
# Received tweet #452
# Received tweet #453
# Received tweet #454
# Received tweet #455
# Received tweet #456
# Received tweet #457
# Received tweet #458
# Received tweet #459
# Received tweet #460
# Received tweet #461
# Received tweet #462
# Received tweet #463
# Received tweet #464
# Received tweet #465
# Received tweet #466
# Received tweet #467
# Received tweet #468
# Received tweet #469
# Received tweet #470
# Received tweet #471
# Received tweet #472
# Received tweet #473
# Received tweet #474
# Received tweet #475
# Received tweet #476
# Received tweet #477
# Received tweet #478
# Received tweet #479
# Received tweet #480
# Received tweet #481
# Received tweet #482
# Received tweet #483
# Received tweet #484
# Received tweet #485
# Received tweet #486
# Received tweet #487
# Received tweet #488
# Received tweet #489
# Received tweet #490
# Received tweet #491
# Received tweet #492
# Received tweet #493
# Received tweet #494
# Received tweet #495
# Received tweet #496
# Received tweet #497
# Received tweet #498
# Received tweet #499
# Received tweet #500
# Received tweet #501
# Received tweet #502
# Received tweet #503
# Received tweet #504
# Received tweet #505
# Received tweet #506
# Received tweet #507
# Received tweet #508
# Received tweet #509
# Received tweet #510
# Received tweet #511
# Received tweet #512
# Received tweet #513
# Received tweet #514
# Received tweet #515
# Received tweet #516
# Received tweet #517
# Received tweet #518
# Received tweet #519
# Received tweet #520
# Received tweet #521
# Received tweet #522
# Received tweet #523
# Received tweet #524
# Received tweet #525
# Received tweet #526
# Received tweet #527
# Received tweet #528
# Received tweet #529
# Received tweet #530
# Received tweet #531
# Received tweet #532
# Received tweet #533
# Received tweet #534
# Received tweet #535
# Received tweet #536
# Received tweet #537
# Received tweet #538
# Received tweet #539
# Received tweet #540
# Received tweet #541
# Received tweet #542
# Received tweet #543
# Received tweet #544
# Received tweet #545
# Received tweet #546
# Received tweet #547
# Received tweet #548
# Received tweet #549
# Received tweet #550
# Received tweet #551
# Received tweet #552
# Received tweet #553
# Received tweet #554
# Received tweet #555
# Received tweet #556
# Received tweet #557
# Received tweet #558
# Received tweet #559
# Received tweet #560
# Received tweet #561
# Received tweet #562
# Received tweet #563
# Received tweet #564
# Received tweet #565
# Received tweet #566
# Received tweet #567
# Received tweet #568
# Received tweet #569
# Received tweet #570
# Received tweet #571
# Received tweet #572
# Received tweet #573
# Received tweet #574
# Received tweet #575
# Received tweet #576
# Received tweet #577
# Received tweet #578
# Received tweet #579
# Received tweet #580
# Received tweet #581
# Received tweet #582
# Received tweet #583
# Received tweet #584
# Received tweet #585
# Received tweet #586
# Received tweet #587
# Received tweet #588
# Received tweet #589
# Received tweet #590
# Received tweet #591
# Received tweet #592
# Received tweet #593
# Received tweet #594
# Received tweet #595
# Received tweet #596
# Received tweet #597
# Received tweet #598
# Received tweet #599
# Received tweet #600
# Received tweet #601
# Received tweet #602
# Received tweet #603
# Received tweet #604
# Received tweet #605
# Received tweet #606
# Received tweet #607
# Received tweet #608
# Received tweet #609
# Received tweet #610
# Received tweet #611
# Received tweet #612
# Received tweet #613
# Received tweet #614
# Received tweet #615
# Received tweet #616
# Received tweet #617
# Received tweet #618
# Received tweet #619
# Received tweet #620
# Received tweet #621
# Received tweet #622
# Received tweet #623
# Received tweet #624
# Received tweet #625
# Received tweet #626
# Received tweet #627
# Received tweet #628
# Received tweet #629
# Received tweet #630
# Received tweet #631
# Received tweet #632
# Received tweet #633
# Received tweet #634
# Received tweet #635
# Received tweet #636
# Received tweet #637
# Received tweet #638
# Received tweet #639
# Received tweet #640
# Received tweet #641
# Received tweet #642
# Received tweet #643
# Received tweet #644
# Received tweet #645
# Received tweet #646
# Received tweet #647
# Received tweet #648
# Received tweet #649
# Received tweet #650
# Received tweet #651
# Received tweet #652
# Received tweet #653
# Received tweet #654
# Received tweet #655
# Received tweet #656
# Received tweet #657
# Received tweet #658
# Received tweet #659
# Received tweet #660
# Received tweet #661
# Received tweet #662
# Received tweet #663
# Received tweet #664
# Received tweet #665
# Received tweet #666
# Received tweet #667
# Received tweet #668
# Received tweet #669
# Received tweet #670
# Received tweet #671
# Received tweet #672
# Received tweet #673
# Received tweet #674
# Received tweet #675
# Received tweet #676
# Received tweet #677
# Received tweet #678
# Received tweet #679
# Received tweet #680
# Received tweet #681
# Received tweet #682
# Received tweet #683
# Received tweet #684
# Received tweet #685
# Received tweet #686
# Received tweet #687
# Received tweet #688
# Received tweet #689
# Received tweet #690
# Received tweet #691
# Received tweet #692
# Received tweet #693
# Received tweet #694
# Received tweet #695
# Received tweet #696
# Received tweet #697
# Received tweet #698
# Received tweet #699
# Received tweet #700
# Received tweet #701
# Received tweet #702
# Received tweet #703
# Received tweet #704
# Received tweet #705
# Received tweet #706
# Received tweet #707
# Received tweet #708
# Received tweet #709
# Received tweet #710
# Received tweet #711
# Received tweet #712
# Received tweet #713
# Received tweet #714
# Received tweet #715
# Received tweet #716
# Received tweet #717
# Received tweet #718
# Received tweet #719
# Received tweet #720
# Received tweet #721
# Received tweet #722
# Received tweet #723
# Received tweet #724
# Received tweet #725
# Received tweet #726
# Received tweet #727
# Received tweet #728
# Received tweet #729
# Received tweet #730
# Received tweet #731
# Received tweet #732
# Received tweet #733
# Received tweet #734
# Received tweet #735
# Received tweet #736
# Received tweet #737
# Received tweet #738
# Received tweet #739
# Received tweet #740
# Received tweet #741
# Received tweet #742
# Received tweet #743
# Received tweet #744
# Received tweet #745
# Received tweet #746
# Received tweet #747
# Received tweet #748
# Received tweet #749
# Received tweet #750
# Received tweet #751
# Received tweet #752
# Received tweet #753
# Received tweet #754
# Received tweet #755
# Received tweet #756
# Received tweet #757
# Received tweet #758
# Received tweet #759
# Received tweet #760
# Received tweet #761
# Received tweet #762
# Received tweet #763
# Received tweet #764
# Received tweet #765
# Received tweet #766
# Received tweet #767
# Received tweet #768
# Received tweet #769
# Received tweet #770
# Received tweet #771
# Received tweet #772
# Received tweet #773
# Received tweet #774
# Received tweet #775
# Received tweet #776
# Received tweet #777
# Received tweet #778
# Received tweet #779
# Received tweet #780
# Received tweet #781
# Received tweet #782
# Received tweet #783
# Received tweet #784
# Received tweet #785
# Received tweet #786
# Received tweet #787
# Received tweet #788
# Received tweet #789
# Received tweet #790
# Received tweet #791
# Received tweet #792
# Received tweet #793
# Received tweet #794
# Received tweet #795
# Received tweet #796
# Received tweet #797
# Received tweet #798
# Received tweet #799
# Received tweet #800
# Received tweet #801
# Received tweet #802
# Received tweet #803
# Received tweet #804
# Received tweet #805
# Received tweet #806
# Received tweet #807
# Received tweet #808
# Received tweet #809
# Received tweet #810
# Received tweet #811
# Received tweet #812
# Received tweet #813
# Received tweet #814
# Received tweet #815
# Received tweet #816
# Received tweet #817
# Received tweet #818
# Received tweet #819
# Received tweet #820
# Received tweet #821
# Received tweet #822
# Received tweet #823
# Received tweet #824
# Received tweet #825
# Received tweet #826
# Received tweet #827
# Received tweet #828
# Received tweet #829
# Received tweet #830
# Received tweet #831
# Received tweet #832
# Received tweet #833
# Received tweet #834
# Received tweet #835
# Received tweet #836
# Received tweet #837
# Received tweet #838
# Received tweet #839
# Received tweet #840
# Received tweet #841
# Received tweet #842
# Received tweet #843
# Received tweet #844
# Received tweet #845
# Received tweet #846
# Received tweet #847
# Received tweet #848
# Received tweet #849
# Received tweet #850
# Received tweet #851
# Received tweet #852
# Received tweet #853
# Received tweet #854
# Received tweet #855
# Received tweet #856
# Received tweet #857
# Received tweet #858
# Received tweet #859
# Received tweet #860
# Received tweet #861
# Received tweet #862
# Received tweet #863
# Received tweet #864
# Received tweet #865
# Received tweet #866
# Received tweet #867
# Received tweet #868
# Received tweet #869
# Received tweet #870
# Received tweet #871
# Received tweet #872
# Received tweet #873
# Received tweet #874
# Received tweet #875
# Received tweet #876
# Received tweet #877
# Received tweet #878
# Received tweet #879
# Received tweet #880
# Received tweet #881
# Received tweet #882
# Received tweet #883
# Received tweet #884
# Received tweet #885
# Received tweet #886
# Received tweet #887
# Received tweet #888
# Received tweet #889
# Received tweet #890
# Received tweet #891
# Received tweet #892
# Received tweet #893
# Received tweet #894
# Received tweet #895
# Received tweet #896
# Received tweet #897
# Received tweet #898
# Received tweet #899
# Received tweet #900
# Received tweet #901
# Received tweet #902
# Received tweet #903
# Received tweet #904
# Received tweet #905
# Received tweet #906
# Received tweet #907
# Received tweet #908
# Received tweet #909
# Received tweet #910
# Received tweet #911
# Received tweet #912
# Received tweet #913
# Received tweet #914
# Received tweet #915
# Received tweet #916
# Received tweet #917
# Received tweet #918
# Received tweet #919
# Received tweet #920
# Received tweet #921
# Received tweet #922
# Received tweet #923
# Received tweet #924
# Received tweet #925
# Received tweet #926
# Received tweet #927
# Received tweet #928
# Received tweet #929
# Received tweet #930
# Received tweet #931
# Received tweet #932
# Received tweet #933
# Received tweet #934
# Received tweet #935
# Received tweet #936
# Received tweet #937
# Received tweet #938
# Received tweet #939
# Received tweet #940
# Received tweet #941
# Received tweet #942
# Received tweet #943
# Received tweet #944
# Received tweet #945
# Received tweet #946
# Received tweet #947
# Received tweet #948
# Received tweet #949
# Received tweet #950
# Received tweet #951
# Received tweet #952
# Received tweet #953
# Received tweet #954
# Received tweet #955
# Received tweet #956
# Received tweet #957
# Received tweet #958
# Received tweet #959
# Received tweet #960
# Received tweet #961
# Received tweet #962
# Received tweet #963
# Received tweet #964
# Received tweet #965
# Received tweet #966
# Received tweet #967
# Received tweet #968
# Received tweet #969
# Received tweet #970
# Received tweet #971
# Received tweet #972
# Received tweet #973
# Received tweet #974
# Received tweet #975
# Received tweet #976
# Received tweet #977
# Received tweet #978
# Received tweet #979
# Received tweet #980
# Received tweet #981
# Received tweet #982
# Received tweet #983
# Received tweet #984
# Received tweet #985
# Received tweet #986
# Received tweet #987
# Received tweet #988
# Received tweet #989
# Received tweet #990
# Received tweet #991
# Received tweet #992
# Received tweet #993
# Received tweet #994
# Received tweet #995
# Received tweet #996
# Received tweet #997
# Received tweet #998
# Received tweet #999
# Received tweet #1000

# %% [markdown]
# * Com os dados encontrados é possível, por exemplo, encontrar as hashtags mais famosas:

# %%
top_hashtags = Counter(hashtag['text'].lower()
                      for tweet in tweets
                      for hashtag in tweet["entities"]["hashtags"])

print(top_hashtags.most_common(5))
# Out:
# [('data', 29), ('ai', 21), ('blockchain', 17), ('fintech', 17), ('bitcoin', 16)]
